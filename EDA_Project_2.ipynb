# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import trim_mean  
from scipy import stats
from scipy.stats import sem

# %%
df = pd.read_csv('../data/datamarket_productos_de_supermercados.csv')
df.head()
# Out:
#                                                  url supermarket  \
# 0  https://www.dia.es/compra-online/productos/per...      dia-es
# 1  https://www.dia.es/compra-online/productos/per...      dia-es
# 2  https://www.dia.es/compra-online/productos/per...      dia-es
# 3  https://www.dia.es/compra-online/productos/per...      dia-es
# 4  https://www.dia.es/compra-online/productos/per...      dia-es
#
#                                             category  \
# 0  perfumeria_e_higiene_cuidado_facial_contorno_d...
# 1  perfumeria_e_higiene_afeitado_espuma_gel_y_cre...
# 2  perfumeria_e_higiene_afeitado_espuma_gel_y_cre...
# 3            perfumeria_e_higiene_colonias_femeninas
# 4            perfumeria_e_higiene_colonias_femeninas
#
#                                                 name description  price  \
# 0                BABARIA contorno de ojos aloe 15 ml         NaN   6.95
# 1  LEA loción hidratante para barba dosificador 7...         NaN   7.95
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8075908 entries, 0 to 8075907
# Data columns (total 10 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   url              object
#  1   supermarket      object
#  2   category         object
#  3   name             object
#  4   description      object
#  5   price            float64
#  6   reference_price  float64
#  7   reference_unit   object
#  8   insert_date      object
#  9   product_id       object
# dtypes: float64(2), object(8)
# memory usage: 616.1+ MB

# %%
df.describe()
# Out:
#               price  reference_price
# count  8.075890e+06     8.075902e+06
# mean   4.746785e+00     1.942013e+01
# std    4.896309e+01     6.314651e+02
# min    8.000000e-02     3.000000e-03
# 25%    1.390000e+00     1.800000e+00
# 50%    2.200000e+00     4.546000e+00
# 75%    3.990000e+00     9.920000e+00
# max    7.915050e+03     1.633333e+05

# %%
df.isnull().sum()
# Out:
# url                      0
# supermarket              0
# category                 0
# name                    86
# description        5106625
# price                   18
# reference_price          6
# reference_unit        5480
# insert_date              0
# product_id               0
# dtype: int64

# %%
null_cols = df.isnull().sum()
null_cols[null_cols > 0]
# Out:
# name                    86
# description        5106625
# price                   18
# reference_price          6
# reference_unit        5480
# dtype: int64

# %%
null_cols = null_cols[null_cols > 0] / len(df) * 100
null_cols
# Out:
# name                0.001065
# description        63.232828
# price               0.000223
# reference_price     0.000074
# reference_unit      0.067856
# dtype: float64

# %%
df2 = df.drop(['product_id', 'url', 'insert_date'], axis=1)

# %%
df2.head()
# Out:
#   supermarket                                           category  \
# 0      dia-es  perfumeria_e_higiene_cuidado_facial_contorno_d...
# 1      dia-es  perfumeria_e_higiene_afeitado_espuma_gel_y_cre...
# 2      dia-es  perfumeria_e_higiene_afeitado_espuma_gel_y_cre...
# 3      dia-es            perfumeria_e_higiene_colonias_femeninas
# 4      dia-es            perfumeria_e_higiene_colonias_femeninas
#
#                                                 name description  price  \
# 0                BABARIA contorno de ojos aloe 15 ml         NaN   6.95
# 1  LEA loción hidratante para barba dosificador 7...         NaN   7.95
# 2  LA TOJA crema de afeitar piel sensible tubo 15...         NaN   2.49
# 3  BONTE colonia be diva fragancia floral frasco ...         NaN   6.99
# 4  BONTE colonia be in love fragancia oriental-fl...         NaN   6.99
#
#    reference_price reference_unit
# 0           463.33              l
# 1           106.00              l
# 2            16.60              l
# ...

# %%
df2.isnull().sum()
# Out:
# supermarket              0
# category                 0
# name                    86
# description        5106625
# price                   18
# reference_price          6
# reference_unit        5480
# dtype: int64

# %%
null_displ = df2.loc[df2['price'].isnull(), ['supermarket', 'category','name', 'price', 'reference_price',]]
null_displ
# Out:
#           supermarket                                           category  \
# 6364896  carrefour-es  productos_frescos_frutas_naranjas_y_otros_citr...
# 7099959        dia-es               despensa_desayunos_y_dulces_bolleria
# 7104429        dia-es  despensa_lacteos_y_huevos_mantequilla_y_margarina
# 7105156        dia-es             despensa_pastas_harinas_y_masas_pastas
# 7115492        dia-es             despensa_pastas_harinas_y_masas_pastas
# 7119122        dia-es  despensa_lacteos_y_huevos_mantequilla_y_margarina
# 7120923        dia-es               despensa_desayunos_y_dulces_bolleria
# 7275360  carrefour-es                          bebidas_alcoholes_ginebra
# 7390454  carrefour-es              bebidas_alcoholes_todos_los_alcoholes
# 7404524  carrefour-es              bebidas_alcoholes_todos_los_alcoholes
# 7412257  carrefour-es              bebidas_alcoholes_todos_los_alcoholes
# 7424746  carrefour-es              bebidas_alcoholes_todos_los_alcoholes
# ...

# %%
df2 = df2[df2['price'].notna()]

# %%
null_displ2 = df2.loc[df2['price'].isnull(), ['supermarket', 'category','name', 'price', 'reference_price',]]
null_displ2
# Out:
# Empty DataFrame
# Columns: [supermarket, category, name, price, reference_price]
# Index: []
